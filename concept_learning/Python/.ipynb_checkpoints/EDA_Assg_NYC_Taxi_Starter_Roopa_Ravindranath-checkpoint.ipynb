# %% [markdown]
# # **New York City Yellow Taxi Data**

# %% [markdown]
# ## Objective
# In this case study you will be learning exploratory data analysis (EDA) with the help of a dataset on yellow taxi rides in New York City. This will enable you to understand why EDA is an important step in the process of data science and machine learning.

# %% [markdown]
# ## **Problem Statement**
# As an analyst at an upcoming taxi operation in NYC, you are tasked to use the 2023 taxi trip data to uncover insights that could help optimise taxi operations. The goal is to analyse patterns in the data that can inform strategic decisions to improve service efficiency, maximise revenue, and enhance passenger experience.

# %% [markdown]
# ## Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Loading
# 2. Data Cleaning
# 3. Exploratory Analysis: Bivariate and Multivariate
# 4. Creating Visualisations to Support the Analysis
# 5. Deriving Insights and Stating Conclusions

# %% [markdown]
# ---

# %% [markdown]
# **NOTE:** The marks given along with headings and sub-headings are cumulative marks for those particular headings/sub-headings.<br>
#
# The actual marks for each task are specified within the tasks themselves.
#
# For example, marks given with heading *2* or sub-heading *2.1* are the cumulative marks, for your reference only. <br>
#
# The marks you will receive for completing tasks are given with the tasks.
#
# Suppose the marks for two tasks are: 3 marks for 2.1.1 and 2 marks for 3.2.2, or
# * 2.1.1 [3 marks]
# * 3.2.2 [2 marks]
#
# then, you will earn 3 marks for completing task 2.1.1 and 2 marks for completing task 3.2.2.

# %% [markdown]
# ---

# %% [markdown]
# ## Data Understanding
# The yellow taxi trip records include fields capturing pick-up and drop-off dates/times, pick-up and drop-off locations, trip distances, itemized fares, rate types, payment types, and driver-reported passenger counts.
#
# The data is stored in Parquet format (*.parquet*). The dataset is from 2009 to 2024. However, for this assignment, we will only be using the data from 2023.
#
# The data for each month is present in a different parquet file. You will get twelve files for each of the months in 2023.
#
# The data was collected and provided to the NYC Taxi and Limousine Commission (TLC) by technology providers like vendors and taxi hailing apps. <br>
#
# You can find the link to the TLC trip records page here: https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page

# %% [markdown]
# ###  Data Description
# You can find the data description here: [Data Dictionary](https://www.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf)

# %% [markdown]
# **Trip Records**
#
#
#
# |Field Name       |description |
# |:----------------|:-----------|
# | VendorID | A code indicating the TPEP provider that provided the record. <br> 1= Creative Mobile Technologies, LLC; <br> 2= VeriFone Inc. |
# | tpep_pickup_datetime | The date and time when the meter was engaged.  |
# | tpep_dropoff_datetime | The date and time when the meter was disengaged.   |
# | Passenger_count | The number of passengers in the vehicle. <br> This is a driver-entered value. |
# | Trip_distance | The elapsed trip distance in miles reported by the taximeter. |
# | PULocationID | TLC Taxi Zone in which the taximeter was engaged |
# | DOLocationID | TLC Taxi Zone in which the taximeter was disengaged |
# |RateCodeID |The final rate code in effect at the end of the trip.<br> 1 = Standard rate <br> 2 = JFK <br> 3 = Newark <br>4 = Nassau or Westchester <br>5 = Negotiated fare <br>6 = Group ride |
# |Store_and_fwd_flag |This flag indicates whether the trip record was held in vehicle memory before sending to the vendor, aka “store and forward,” because the vehicle did not have a connection to the server.  <br>Y= store and forward trip <br>N= not a store and forward trip |
# |Payment_type| A numeric code signifying how the passenger paid for the trip. <br> 1 = Credit card <br>2 = Cash <br>3 = No charge <br>4 = Dispute <br>5 = Unknown <br>6 = Voided trip |
# |Fare_amount| The time-and-distance fare calculated by the meter. <br>Extra Miscellaneous extras and surcharges.  Currently, this only includes the 0.50 and 1 USD rush hour and overnight charges. |
# |MTA_tax |0.50 USD MTA tax that is automatically triggered based on the metered rate in use. |
# |Improvement_surcharge | 0.30 USD improvement surcharge assessed trips at the flag drop. The improvement surcharge began being levied in 2015. |
# |Tip_amount |Tip amount – This field is automatically populated for credit card tips. Cash tips are not included. |
# | Tolls_amount | Total amount of all tolls paid in trip.  |
# | total_amount | The total amount charged to passengers. Does not include cash tips. |
# |Congestion_Surcharge |Total amount collected in trip for NYS congestion surcharge. |
# | Airport_fee | 1.25 USD for pick up only at LaGuardia and John F. Kennedy Airports|
#
# Although the amounts of extra charges and taxes applied are specified in the data dictionary, you will see that some cases have different values of these charges in the actual data.

# %% [markdown]
# **Taxi Zones**
#
# Each of the trip records contains a field corresponding to the location of the pickup or drop-off of the trip, populated by numbers ranging from 1-263.
#
# These numbers correspond to taxi zones, which may be downloaded as a table or map/shapefile and matched to the trip records using a join.
#
# This is covered in more detail in later sections.

# %% [markdown]
# ---

# %% [markdown]
# ## **1** Data Preparation
#
# <font color = red>[5 marks]</font> <br>

# %% [markdown]
# ### Import Libraries

# %%
# Import warnings
import numpy as np
import pandas as pd

# %%
# Import the libraries you will be using for analysis

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Recommended versions
# numpy version: 1.26.4
# pandas version: 2.2.2
# matplotlib version: 3.10.0
# seaborn version: 0.13.2

# Check versions
print("numpy version:", np.__version__)
print("pandas version:", pd.__version__)
print("matplotlib version:", plt.matplotlib.__version__)
print("seaborn version:", sns.__version__)
# Out:
# numpy version: 2.4.0
# pandas version: 2.3.3
# matplotlib version: 3.10.8
# seaborn version: 0.13.2

# %%
pip install fastparquet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **1.1** Load the dataset
# <font color = red>[5 marks]</font> <br>

# %% [markdown]
# You will see twelve files, one for each month.
#
# To read parquet files with Pandas, you have to follow a similar syntax as that for CSV files.
#
# `df = pd.read_parquet('file.parquet')`

# %%
# Try loading one file

# df = pd.read_parquet('2023-1.parquet')
# df.info()
df = pd.read_parquet("yellow_tripdata_2023-01.parquet", engine="fastparquet")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(1)
# ...

# %% [markdown]
# How many rows are there? Do you think handling such a large number of rows is computationally feasible when we have to combine the data for all twelve months into one?
#
# To handle this, we need to sample a fraction of data from each of the files. How to go about that? Think of a way to select only some portion of the data from each month's file that accurately represents the trends.

# %% [markdown]
# #### Sampling the Data
# > One way is to take a small percentage of entries for pickup in every hour of a date. So, for all the days in a month, we can iterate through the hours and select 5% values randomly from those. Use `tpep_pickup_datetime` for this. Separate date and hour from the datetime values and then for each date, select some fraction of trips for each of the 24 hours.
#
# To sample data, you can use the `sample()` method. Follow this syntax:
#
# ```Python
# # sampled_data is an empty DF to keep appending sampled data of each hour
# # hour_data is the DF of entries for an hour 'X' on a date 'Y'
#
# sample = hour_data.sample(frac = 0.05, random_state = 42)
# # sample 0.05 of the hour_data
# # random_state is just a seed for sampling, you can define it yourself
#
# sampled_data = pd.concat([sampled_data, sample]) # adding data for this hour to the DF
# ```
#
# This *sampled_data* will contain 5% values selected at random from each hour.
#
# Note that the code given above is only the part that will be used for sampling and not the complete code required for sampling and combining the data files.
#
# Keep in mind that you sample by date AND hour, not just hour. (Why?)

# %% [markdown]
# ---

# %% [markdown]
# **1.1.1** <font color = red>[5 marks]</font> <br>
# Figure out how to sample and combine the files.

# %% [markdown]
# **Note:** It is not mandatory to use the method specified above. While sampling, you only need to make sure that your sampled data represents the overall data of all the months accurately.

# %%
# Sample the data
# It is recommmended to not load all the files at once to avoid memory overload
files = ["yellow_tripdata_2023-01.parquet","yellow_tripdata_2023-02.parquet","yellow_tripdata_2023-03.parquet","yellow_tripdata_2023-04.parquet",
        "yellow_tripdata_2023-05.parquet","yellow_tripdata_2023-06.parquet","yellow_tripdata_2023-07.parquet","yellow_tripdata_2023-08.parquet",
        "yellow_tripdata_2023-09.parquet","yellow_tripdata_2023-10.parquet","yellow_tripdata_2023-11.parquet","yellow_tripdata_2023-12.parquet"]

sampled_data = pd.DataFrame()


for file in files:
    df = pd.read_parquet(file, engine="fastparquet")
    # 2023-01-05 08:23:17
    # 2023-01-05 08:45:02
    # Group it as 5 Jan, 8 am
    df["pickup_date"] = df["tpep_pickup_datetime"].dt.date
    df["pickup_hour"] = df["tpep_pickup_datetime"].dt.hour
    groupData = df.groupby(["pickup_date", "pickup_hour"])
    fileSamples = []
    for key,hr_df in groupData:
    
        if(len(hr_df)<20):
            sample = hr_df.sample(n=1, random_state=42)
        else:
            sample = hr_df.sample(frac=0.05,random_state=42)
        fileSamples.append(sample)
        
    file_sample_df = pd.concat(fileSamples,ignore_index=True)
    sampled_data = pd.concat([sampled_data,file_sample_df],ignore_index=True)
    del df

print(sampled_data)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             2.0  2008-12-31 23:01:42   2009-01-01 14:29:11              1.0
# 1             2.0  2022-10-24 17:37:47   2022-10-24 17:37:51              1.0
# 2             2.0  2022-10-24 20:01:46   2022-10-24 20:01:48              1.0
# 3             2.0  2022-10-24 21:45:35   2022-10-24 21:45:38              1.0
# 4             2.0  2022-10-24 23:15:32   2022-10-24 23:15:42              1.0
# ...           ...                  ...                   ...              ...
# 1915726       2.0  2024-01-01 00:01:58   2024-01-01 00:10:04              3.0
# 1915727       2.0  2024-01-03 10:00:04   2024-01-03 11:08:22              1.0
# 1915728       2.0  2024-01-03 17:00:52   2024-01-03 17:01:05              2.0
# 1915729       2.0  2024-01-03 18:43:26   2024-01-03 18:43:29              2.0
# 1915730       2.0  2024-01-03 19:42:57   2024-01-03 20:15:55              1.0
#
# ...

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# ----------- sampling done is above cell ---------------


# Take a small percentage of entries from each hour of every date.
# Iterating through the monthly data:
#   read a month file -> day -> hour: append sampled data -> move to next hour -> move to next day after 24 hours -> move to next month file
# Create a single dataframe for the year combining all the monthly data

# Select the folder having data files
import os

# Select the folder having data files
os.chdir('/content/Assignments/EDA/data_NYC_Taxi/trip_records')

# Create a list of all the twelve files to read
file_list = os.listdir()

# initialise an empty dataframe
df = pd.DataFrame()


# iterate through the list of files and sample one by one:
for file_name in file_list:
    try:
        # file path for the current file
        file_path = os.path.join(os.getcwd(), file_name)

        # Reading the current file



        # We will store the sampled data for the current date in this df by appending the sampled data from each hour to this
        # After completing iteration through each date, we will append this data to the final dataframe.
        sampled_data = pd.DataFrame()

        # Loop through dates and then loop through every hour of each date

            # Iterate through each hour of the selected date

                # Sample 5% of the hourly data randomly

                # add data of this hour to the dataframe

        # Concatenate the sampled data of all the dates to a single dataframe
        # df = # we initialised this empty DF earlier

    except Exception as e:
        print(f"Error reading file {file_name}: {e}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 13
#      10 import os
#      12 # Select the folder having data files
# ---> 13 os.chdir('/content/Assignments/EDA/data_NYC_Taxi/trip_records')
#      15 # Create a list of all the twelve files to read
#      16 file_list = os.listdir()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Assignments/EDA/data_NYC_Taxi/trip_records'

# %% [markdown]
# After combining the data files into one DataFrame, convert the new DataFrame to a CSV or parquet file and store it to use directly.
#
# Ideally, you can try keeping the total entries to around 250,000 to 300,000.

# %%
# Store the df in csv/parquet
# df.to_parquet('')
len(sampled_data)
final_df = sampled_data.sample(n=300000, random_state=42)
final_df.to_parquet("taxi_2023_sampled.parquet", index=False)

# %% [markdown]
# ## **2** Data Cleaning
# <font color = red>[30 marks]</font> <br>

# %% [markdown]
# Now we can load the new data directly.

# %%
# Load the new data file
df = pd.read_parquet("taxi_2023_sampled.parquet", engine="fastparquet")

# %%
# df.head()
df.head(5)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       2.0  2023-04-14 11:12:06   2023-04-14 11:26:47              1.0
# 1       2.0  2023-05-09 09:07:35   2023-05-09 09:18:42              1.0
# 2       1.0  2023-11-14 09:50:02   2023-11-14 11:18:27              1.0
# 3       2.0  2023-04-06 13:15:55   2023-04-06 13:37:31              1.0
# 4       2.0  2023-12-12 19:39:36   2023-12-12 19:46:47              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.07         1.0                  N         238.0         143.0
# 1           0.96         1.0                  N         162.0         141.0
# 2           9.50        99.0                  N         129.0         100.0
# 3           3.64         1.0                  N          50.0         113.0
# 4           0.87         1.0                  N         170.0         164.0
#
#    payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
# df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               300000 non-null  float64
#  1   tpep_pickup_datetime   300000 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime  300000 non-null  datetime64[ns]
#  3   passenger_count        289795 non-null  float64
#  4   trip_distance          300000 non-null  float64
#  5   RatecodeID             289795 non-null  float64
#  6   store_and_fwd_flag     289795 non-null  object
#  7   PULocationID           300000 non-null  float64
#  8   DOLocationID           300000 non-null  float64
#  9   payment_type           300000 non-null  float64
#  10  fare_amount            300000 non-null  float64
#  11  extra                  300000 non-null  float64
#  12  mta_tax                300000 non-null  float64
# ...

# %% [markdown]
# #### **2.1** Fixing Columns
# <font color = red>[10 marks]</font> <br>
#
# Fix/drop any columns as you seem necessary in the below sections

# %% [markdown]
# **2.1.1** <font color = red>[2 marks]</font> <br>
#
# Fix the index and drop unnecessary columns

# %%
# Fix the index and drop any columns that are not needed

# remove index
df = df.reset_index(drop=True)

# columns created for samplinh: pickup_date, pickup_hour
df.drop(columns=["pickup_date","pickup_hour"])
df.nunique()
# Out:
# VendorID                      3
# tpep_pickup_datetime     298041
# tpep_dropoff_datetime    298121
# passenger_count               8
# trip_distance              2998
# RatecodeID                    7
# store_and_fwd_flag            2
# PULocationID                246
# DOLocationID                259
# payment_type                  5
# fare_amount                4299
# extra                        43
# mta_tax                       6
# tip_amount                 2680
# tolls_amount                305
# improvement_surcharge         5
# total_amount              10007
# congestion_surcharge          4
# airport_fee                   3
# pickup_date                 369
# pickup_hour                  24
# Airport_fee                   5
# dtype: int64

# %% [markdown]
# **2.1.2** <font color = red>[3 marks]</font> <br>
# There are two airport fee columns. This is possibly an error in naming columns. Let's see whether these can be combined into a single column.

# %%
# Combine the two airport fee columns
# print(df[["airport_fee", "Airport_fee"]].describe())

# print("\n")
# both_present = df[df["airport_fee"].notna() & df["Airport_fee"].notna()]
# print(both_present[["airport_fee", "Airport_fee"]].head())

# print("\n")
# print(df["airport_fee"].notna().sum())
# print(df["Airport_fee"].notna().sum())


df["Airport_fee"] = df["Airport_fee"].fillna(df["airport_fee"])
print(df["Airport_fee"])
df = df.drop(columns=["airport_fee"])
# Out:
# 0         0.00
# 1         0.00
# 2         0.00
# 3         0.00
# 4         0.00
#           ...
# 299995    0.00
# 299996    1.75
# 299997    0.00
# 299998    0.00
# 299999    1.75
# Name: Airport_fee, Length: 300000, dtype: float64

# %% [markdown]
# **2.1.3** <font color = red>[5 marks]</font> <br>
# Fix columns with negative (monetary) values

# %%
# check where values of fare amount are negative
negative_fare_df = df[df["fare_amount"] < 0]
negative_fare_df.head()
len(negative_fare_df)
# Out:
# 2962

# %% [markdown]
# Did you notice something different in the `RatecodeID` column for above records?

# %%
# Analyse RatecodeID for the negative fare amounts
negative_fare_df[["fare_amount","RatecodeID"]].head(20)
# Out:
#       fare_amount  RatecodeID
# 106          -6.5         1.0
# 312          -0.5         NaN
# 341          -5.8         1.0
# 348          -6.5         1.0
# 524          -0.5         NaN
# 541         -16.3         1.0
# 652         -24.7         1.0
# 658          -3.7         1.0
# 666         -10.7         1.0
# 780         -10.7         1.0
# 835          -3.0         1.0
# 998         -70.0         2.0
# 1054        -10.7         1.0
# 1083        -11.4         1.0
# 1157        -19.1         1.0
# 1167         -5.1         1.0
# 1179        -70.0         2.0
# 1280        -20.5         1.0
# 1323        -13.5         1.0
# 1330        -15.6         1.0

# %%
# Find which columns have negative values
num_cols = df.select_dtypes(include=["number"]).columns
neg_counts = (df[num_cols] < 0).sum()
neg_counts[neg_counts > 0]
# Out:
# fare_amount              2962
# extra                    1473
# mta_tax                  2831
# tip_amount                 15
# tolls_amount              184
# improvement_surcharge    2925
# total_amount             2925
# congestion_surcharge     2343
# Airport_fee               367
# dtype: int64

# %%
# fix these negative values
invalid_trips = df[df["total_amount"] < 0]
len(invalid_trips)

negative_amount_df = df[df["total_amount"] < 0]
negative_amount_df[["total_amount","RatecodeID"]].head(20)

#means lower rating generally have negative amount which might be part of refund/cancellarion: No use of taking absolute
df = df[df["total_amount"] >= 0]

# %%
df
num_cols = df.select_dtypes(include=["number"]).columns
neg_counts = (df[num_cols] < 0).sum()
neg_counts[neg_counts > 0]
# Out:
# fare_amount    47
# dtype: int64

# %%
len(df) 
# approx 29700

# fare amopunt => 47 neg rows is very small hence we can drop
df = df[df["fare_amount"] >= 0]
(df.select_dtypes("number") < 0).sum()
# Out:
# VendorID                 0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# pickup_hour              0
# Airport_fee              0
# dtype: int64

# %% [markdown]
# ### **2.2** Handling Missing Values
# <font color = red>[10 marks]</font> <br>

# %% [markdown]
# **2.2.1**  <font color = red>[2 marks]</font> <br>
# Find the proportion of missing values in each column

# %%
# Find the proportion of missing values in each column

df.isna().sum()
(df.isna().mean() * 100).round(2)
# Out:
# VendorID                 0.00
# tpep_pickup_datetime     0.00
# tpep_dropoff_datetime    0.00
# passenger_count          3.42
# trip_distance            0.00
# RatecodeID               3.42
# store_and_fwd_flag       3.42
# PULocationID             0.00
# DOLocationID             0.00
# payment_type             0.00
# fare_amount              0.00
# extra                    0.00
# mta_tax                  0.00
# tip_amount               0.00
# tolls_amount             0.00
# improvement_surcharge    0.00
# total_amount             0.00
# congestion_surcharge     3.42
# pickup_date              0.00
# pickup_hour              0.00
# Airport_fee              3.42
# dtype: float64

# %% [markdown]
# **2.2.2**  <font color = red>[3 marks]</font> <br>
# Handling missing values in `passenger_count`

# %%
# Display the rows with null values
# Impute NaN values in 'passenger_count'

df[df["passenger_count"].isna()].head()

# replace with meduan
median_pc = df.loc[df["passenger_count"] > 0, "passenger_count"].median()
df.loc[df["passenger_count"].isna(), "passenger_count"] = median_pc

# %%
(df["passenger_count"] == 0).sum()
# Out:
# np.int64(4653)

# %%
df.loc[df["passenger_count"] == 0, "passenger_count"] = median_pc

# %% [markdown]
# Did you find zeroes in passenger_count? Handle these.

# %% [markdown]
# **2.2.3**  <font color = red>[2 marks]</font> <br>
# Handle missing values in `RatecodeID`

# %%
# Fix missing values in 'RatecodeID'
df[df["RatecodeID"].isna()].head()
df["RatecodeID"].dropna().unique()
# Out:
# array([ 1., 99.,  5.,  2.,  4.,  3.,  6.])

# %%
valid_codes = [1,2,3,4,5,6]
# Bring all to valid rating
df.loc[~df["RatecodeID"].isin(valid_codes), "RatecodeID"] = np.nan

# %%
df = df.copy()
mode_rate = df["RatecodeID"].mode()[0]
df.loc[:, "RatecodeID"] = df["RatecodeID"].fillna(mode_rate)

# %% [markdown]
# **2.2.4**  <font color = red>[3 marks]</font> <br>
# Impute NaN in `congestion_surcharge`

# %%
# handle null values in congestion_surcharge

df[df["congestion_surcharge"].isna()]
df.loc[:,"congestion_surcharge"] = df["congestion_surcharge"].fillna(0)
df[df["congestion_surcharge"].isna()]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, pickup_date, pickup_hour, Airport_fee]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Are there missing values in other columns? Did you find NaN values in some other set of columns? Handle those missing values below.

# %%
# Handle any remaining missing values

df.isna().sum()
# Out:
# VendorID                     0
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count              0
# trip_distance                0
# RatecodeID                   0
# store_and_fwd_flag       10158
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# pickup_date                  0
# pickup_hour                  0
# Airport_fee              10158
# dtype: int64

# %%
df["store_and_fwd_flag"].unique()
# Out:
# array(['N', None, 'Y'], dtype=object)

# %%
df["store_and_fwd_flag"].value_counts(dropna=False)
mode_flag = df["store_and_fwd_flag"].mode()[0]
df.loc[:, "store_and_fwd_flag"] = df["store_and_fwd_flag"].fillna(mode_flag)
df["store_and_fwd_flag"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Airport_fee"].unique()
# Out:
# array([0.  , 1.75,  nan, 1.25])

# %%
df.loc[:, "Airport_fee"] = df["Airport_fee"].fillna(0)
df.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# pickup_date              0
# pickup_hour              0
# Airport_fee              0
# dtype: int64

# %% [markdown]
# ### **2.3** Handling Outliers
# <font color = red>[10 marks]</font> <br>

# %% [markdown]
# Before we start fixing outliers, let's perform outlier analysis.

# %%
# Describe the data and check if there are any potential outliers present
# Check for potential out of place values in various columns
df.describe()
# Out:
#             VendorID           tpep_pickup_datetime  \
# count  297028.000000                         297028
# mean        1.731473  2023-07-02 21:49:50.431188224
# min         1.000000            2001-01-01 00:08:31
# 25%         1.000000            2023-04-02 21:10:23
# 50%         2.000000     2023-06-27 19:34:28.500000
# 75%         2.000000     2023-10-06 19:45:10.500000
# max         6.000000            2023-12-31 23:57:18
# std         0.448104                            NaN
#
#                tpep_dropoff_datetime  passenger_count  trip_distance  \
# count                         297028    297028.000000  297028.000000
# mean   2023-07-02 22:07:16.543952384         1.373103       4.648066
# min              2001-01-01 16:01:27         1.000000       0.000000
# 25%              2023-04-02 21:19:33         1.000000       1.040000
# 50%       2023-06-27 19:47:23.500000         1.000000       1.790000
# 75%       2023-10-06 20:05:59.500000         1.000000       3.400000
# ...

# %%
df["passenger_count"].value_counts().sort_index()
# Out:
# passenger_count
# 1.0    230461
# 2.0     43519
# 3.0     10713
# 4.0      6036
# 5.0      3732
# 6.0      2564
# 8.0         3
# Name: count, dtype: int64

# %%
df["trip_distance"].describe()
# Out:
# count    297028.000000
# mean          4.648066
# std         337.615416
# min           0.000000
# 25%           1.040000
# 50%           1.790000
# 75%           3.400000
# max      126360.460000
# Name: trip_distance, dtype: float64

# %%
df["fare_amount"].describe()
# Out:
# count    297028.000000
# mean         19.870864
# std          18.424106
# min           0.000000
# 25%           9.300000
# 50%          13.500000
# 75%          21.900000
# max         870.000000
# Name: fare_amount, dtype: float64

# %%
df["tip_amount"].describe()
# Out:
# count    297028.000000
# mean          3.554430
# std           4.102554
# min           0.000000
# 25%           1.000000
# 50%           2.850000
# 75%           4.420000
# max         251.290000
# Name: tip_amount, dtype: float64

# %%
df["payment_type"].value_counts(dropna=False)
# Out:
# payment_type
# 1.0    233563
# 2.0     49732
# 0.0     10158
# 4.0      2092
# 3.0      1483
# Name: count, dtype: int64

# %% [markdown]
# **2.3.1**  <font color = red>[10 marks]</font> <br>
# Based on the above analysis, it seems that some of the outliers are present due to errors in registering the trips. Fix the outliers.
#
# Some points you can look for:
# - Entries where `trip_distance` is nearly 0 and `fare_amount` is more than 300
# - Entries where `trip_distance` and `fare_amount` are 0 but the pickup and dropoff zones are different (both distance and fare should not be zero for different zones)
# - Entries where `trip_distance` is more than 250  miles.
# - Entries where `payment_type` is 0 (there is no payment_type 0 defined in the data dictionary)
#
# These are just some suggestions. You can handle outliers in any way you wish, using the insights from above outlier analysis.

# %% [markdown]
# How will you fix each of these values? Which ones will you drop and which ones will you replace?

# %% [markdown]
# First, let us remove 7+ passenger counts as there are very less instances.

# %%
# remove passenger_count > 6
df = df[df["passenger_count"] <= 6]

# %%
# Continue with outlier handling

# entry error as fare amount is too high compared to trip distance
df[(df["trip_distance"] < 0.1) & (df["fare_amount"] > 300)].shape
#remove
df = df[~((df["trip_distance"] < 0.1) & (df["fare_amount"] > 300))]

# Trips with different start end zone but trip distance is 0 and fare amount is 0

invalid_trips = df[
    (df["trip_distance"] == 0) &
    (df["fare_amount"] == 0) &
    (df["PULocationID"] != df["DOLocationID"])
]
print("Invalid trips:",invalid_trips.shape)
print("\n")

df = df[~(
    (df["trip_distance"] == 0) &
    (df["fare_amount"] == 0) &
    (df["PULocationID"] != df["DOLocationID"])
)]
# Out:
# Invalid trips: (9, 21)

# %%
df[df["trip_distance"] < 0]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, pickup_date, pickup_hour, Airport_fee]
# Index: []
#
# [0 rows x 21 columns]

# %%
df = df[df["trip_distance"] <= 250]

# %%
valid_payment = [1,2,3,4,5,6]
df = df[df["payment_type"].isin(valid_payment)]

# %%
df.describe()
# Out:
#             VendorID           tpep_pickup_datetime  \
# count  286846.000000                         286846
# mean        1.734690  2023-07-01 23:44:04.562691840
# min         1.000000            2001-01-01 00:08:31
# 25%         1.000000            2023-04-02 01:43:28
# 50%         2.000000            2023-06-26 15:31:01
# 75%         2.000000  2023-10-05 20:13:39.249999872
# max         2.000000            2023-12-31 23:57:18
# std         0.441499                            NaN
#
#                tpep_dropoff_datetime  passenger_count  trip_distance  \
# count                         286846    286846.000000  286846.000000
# mean   2023-07-02 00:01:26.776319488         1.386242       3.449730
# min              2001-01-01 16:01:27         1.000000       0.000000
# 25%    2023-04-02 01:55:34.750000128         1.000000       1.050000
# 50%              2023-06-26 15:50:48         1.000000       1.780000
# 75%    2023-10-05 20:28:14.750000128         1.000000       3.380000
# ...

# %%
df.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# pickup_date              0
# pickup_hour              0
# Airport_fee              0
# dtype: int64

# %%
# Do any columns need standardising?

# these are categorical columns:
cat_cols = ["VendorID","RatecodeID","payment_type","PULocationID","DOLocationID"]
for c in cat_cols:
    df[c] = df[c].astype("category")

# %%
df["passenger_count"] = df["passenger_count"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 286846 entries, 0 to 299999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               286846 non-null  category
#  1   tpep_pickup_datetime   286846 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime  286846 non-null  datetime64[ns]
#  3   passenger_count        286846 non-null  int64
#  4   trip_distance          286846 non-null  float64
#  5   RatecodeID             286846 non-null  category
#  6   store_and_fwd_flag     286846 non-null  object
#  7   PULocationID           286846 non-null  category
#  8   DOLocationID           286846 non-null  category
#  9   payment_type           286846 non-null  category
#  10  fare_amount            286846 non-null  float64
#  11  extra                  286846 non-null  float64
#  12  mta_tax                286846 non-null  float64
# ...

# %%
df["store_and_fwd_flag"] = df["store_and_fwd_flag"].map({"N":0, "Y":1})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 286846 entries, 0 to 299999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               286846 non-null  category
#  1   tpep_pickup_datetime   286846 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime  286846 non-null  datetime64[ns]
#  3   passenger_count        286846 non-null  int64
#  4   trip_distance          286846 non-null  float64
#  5   RatecodeID             286846 non-null  category
#  6   store_and_fwd_flag     286846 non-null  int64
#  7   PULocationID           286846 non-null  category
#  8   DOLocationID           286846 non-null  category
#  9   payment_type           286846 non-null  category
#  10  fare_amount            286846 non-null  float64
#  11  extra                  286846 non-null  float64
#  12  mta_tax                286846 non-null  float64
# ...

# %%
df = df.drop(columns=["pickup_date", "pickup_hour"], errors="ignore")
# created for sampling

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 286846 entries, 0 to 299999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               286846 non-null  category
#  1   tpep_pickup_datetime   286846 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime  286846 non-null  datetime64[ns]
#  3   passenger_count        286846 non-null  int64
#  4   trip_distance          286846 non-null  float64
#  5   RatecodeID             286846 non-null  category
#  6   store_and_fwd_flag     286846 non-null  int64
#  7   PULocationID           286846 non-null  category
#  8   DOLocationID           286846 non-null  category
#  9   payment_type           286846 non-null  category
#  10  fare_amount            286846 non-null  float64
#  11  extra                  286846 non-null  float64
#  12  mta_tax                286846 non-null  float64
# ...

# %% [markdown]
# ## **3** Exploratory Data Analysis
# <font color = red>[90 marks]</font> <br>

# %%
df.columns.tolist()
# Out:
# ['VendorID',
#  'tpep_pickup_datetime',
#  'tpep_dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'congestion_surcharge',
#  'Airport_fee']

# %% [markdown]
# #### **3.1** General EDA: Finding Patterns and Trends
# <font color = red>[40 marks]</font> <br>

# %% [markdown]
# **3.1.1** <font color = red>[3 marks]</font> <br>
# Categorise the varaibles into Numerical or Categorical.
# * `VendorID`:
# * `tpep_pickup_datetime`:
# * `tpep_dropoff_datetime`:
# * `passenger_count`:
# * `trip_distance`:
# * `RatecodeID`:
# * `PULocationID`:
# * `DOLocationID`:
# * `payment_type`:
# * `pickup_hour`:
# * `trip_duration`:
#
#
# The following monetary parameters belong in the same category, is it categorical or numerical?
#
#
# * `fare_amount`
# * `extra`
# * `mta_tax`
# * `tip_amount`
# * `tolls_amount`
# * `improvement_surcharge`
# * `total_amount`
# * `congestion_surcharge`
# * `airport_fee`

# %% [markdown]
# ##### Temporal Analysis

# %% [markdown]
# **3.1.2** <font color = red>[5 marks]</font> <br>
# Analyse the distribution of taxi pickups by hours, days of the week, and months.

# %%
# Find and show the hourly trends in taxi pickups
df["pickup_hour"] = df["tpep_pickup_datetime"].dt.hour


hour_counts = df["pickup_hour"].value_counts().sort_index()
hour_counts
# Out:
# pickup_hour
# 0      7963
# 1      5269
# 2      3561
# 3      2272
# 4      1532
# 5      1606
# 6      3751
# 7      7803
# 8     10725
# 9     12298
# 10    13485
# 11    14639
# 12    15796
# 13    15964
# 14    17477
# 15    17785
# 16    17963
# 17    19405
# 18    20259
# 19    18139
# 20    16350
# 21    16059
# 22    14908
# 23    11837
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
hour_counts.plot(kind="bar")
plt.title("Taxi Pickups by Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Pickups")
plt.show()

# %%
df["pickup_month"] = df["tpep_pickup_datetime"].dt.month


month_counts = df["pickup_month"].value_counts().sort_index()
month_counts
# Out:
# pickup_month
# 1     23102
# 2     21806
# 3     25831
# 4     24944
# 5     26415
# 6     24893
# 7     21974
# 8     21019
# 9     21293
# 10    26032
# 11    24809
# 12    24728
# Name: count, dtype: int64

# %%
# Show the monthly trends in pickups

plt.figure(figsize=(8,4))
month_counts.plot(kind="bar")
plt.title("Taxi Pickups by Month")
plt.xlabel("Month of the year")
plt.ylabel("Number of Pickups")
plt.show()

# %%
df["pickup_weekday"] = df["tpep_pickup_datetime"].dt.day_name()
weekday_counts = df["pickup_weekday"].value_counts()
weekday_counts
# Out:
# pickup_weekday
# Thursday     45144
# Wednesday    43910
# Friday       42626
# Tuesday      41686
# Saturday     41271
# Monday       36200
# Sunday       36009
# Name: count, dtype: int64

# %%
# Find and show the daily trends in taxi pickups (days of the week)

order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
weekday_counts = weekday_counts.reindex(order)
plt.figure(figsize=(8,4))
weekday_counts.plot(kind="bar")
plt.title("Taxi Pickups by Day of Week")
plt.xlabel("Day of Week")
plt.ylabel("Number of Pickups")
plt.show()

# %% [markdown]
# ##### Financial Analysis

# %% [markdown]
# Take a look at the financial parameters like `fare_amount`, `tip_amount`, `total_amount`, and also `trip_distance`. Do these contain zero/negative values?

# %%
# Analyse the above parameters
financial_cols = ["fare_amount","tip_amount","total_amount","trip_distance"]

for col in financial_cols:
    print(col, "negative count:", (df[col] < 0).sum())
# Out:
# fare_amount negative count: 0
# tip_amount negative count: 0
# total_amount negative count: 0
# trip_distance negative count: 0

# %% [markdown]
# Do you think it is beneficial to create a copy DataFrame leaving out the zero values from these?

# %% [markdown]
# **3.1.3** <font color = red>[2 marks]</font> <br>
# Filter out the zero values from the above columns.
#
# **Note:** The distance might be 0 in cases where pickup and drop is in the same zone. Do you think it is suitable to drop such cases of zero distance?

# %%
# Create a df with non zero entries for the selected parameters.
df_filtered = df[(df["fare_amount"] > 0) & (df["total_amount"] > 0) & (df["trip_distance"] > 0)]
df_filtered
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           2.0  2023-04-14 11:12:06   2023-04-14 11:26:47                1
# 1           2.0  2023-05-09 09:07:35   2023-05-09 09:18:42                1
# 2           1.0  2023-11-14 09:50:02   2023-11-14 11:18:27                1
# 3           2.0  2023-04-06 13:15:55   2023-04-06 13:37:31                1
# 4           2.0  2023-12-12 19:39:36   2023-12-12 19:46:47                1
# ...         ...                  ...                   ...              ...
# 299995      2.0  2023-02-14 20:06:25   2023-02-14 20:16:44                1
# 299996      2.0  2023-05-10 23:22:44   2023-05-10 23:56:38                1
# 299997      2.0  2023-04-05 13:40:58   2023-04-05 13:45:36                1
# 299998      1.0  2023-10-10 13:18:32   2023-10-10 14:01:53                1
# 299999      2.0  2023-09-17 00:02:43   2023-09-17 00:14:22                1
#
# ...

# %% [markdown]
# **3.1.4** <font color = red>[3 marks]</font> <br>
# Analyse the monthly revenue (`total_amount`) trend

# %%
# Group data by month and analyse monthly revenue

df_filtered = df_filtered.copy()
df_filtered["pickup_month"] = df_filtered["tpep_pickup_datetime"].dt.month_name()
monthly_revenue = df_filtered.groupby("pickup_month")["total_amount"].sum()

month_order = ["January","February","March","April","May","June","July","August","September","October","November","December"]
monthly_revenue = monthly_revenue.reindex(month_order)

plt.figure(figsize=(10,5))
monthly_revenue.plot(kind="bar")
plt.title("Monthly Revenue Trend (Total Amount)")
plt.xlabel("Month")
plt.ylabel("Total Revenue")
plt.show()

# %% [markdown]
# **3.1.5** <font color = red>[3 marks]</font> <br>
# Show the proportion of each quarter of the year in the revenue

# %%
# Calculate proportion of each quarter

df_filtered = df_filtered.copy()
df_filtered["pickup_quarter"] = df_filtered["tpep_pickup_datetime"].dt.quarter

quarter_revenue = df_filtered.groupby("pickup_quarter")["total_amount"].sum().sort_index()
quarter_prop = quarter_revenue / quarter_revenue.sum()
quarter_pct = quarter_prop * 100

quarter_pct
# Out:
# pickup_quarter
# 1    23.664218
# 2    26.745413
# 3    22.809550
# 4    26.780819
# Name: total_amount, dtype: float64

# %%
plt.figure(figsize=(6,6))
quarter_prop.plot(kind="pie", autopct="%1.1f%%")
plt.title("Revenue Proportion by Quarter")
plt.ylabel("")
plt.show()

# %% [markdown]
# **3.1.6** <font color = red>[3 marks]</font> <br>
# Visualise the relationship between `trip_distance` and `fare_amount`. Also find the correlation value for these two.
#
# **Hint:** You can leave out the trips with trip_distance = 0

# %%
# Show how trip fare is affected by distance
df_dist = df[df["trip_distance"] > 0].copy()
plt.figure(figsize=(6,5))
plt.scatter(df_dist["trip_distance"], df_dist["fare_amount"], alpha=0.3)
plt.title("Trip Distance vs Fare Amount")
plt.xlabel("Trip Distance (miles)")
plt.ylabel("Fare ($)")
plt.show()

# %%
corr_val = df_dist["trip_distance"].corr(df_dist["fare_amount"])
print("Correlation between trip_distance and fare_amount:", corr_val)
# Out:
# Correlation between trip_distance and fare_amount: 0.9441308508893959

# %% [markdown]
# **3.1.7** <font color = red>[5 marks]</font> <br>
# Find and visualise the correlation between:
# 1. `fare_amount` and trip duration (pickup time to dropoff time)
# 2. `fare_amount` and `passenger_count`
# 3. `tip_amount` and `trip_distance`

# %%
# Show relationship between fare and trip duration
df_filtered = df_filtered.copy()

df_filtered["trip_duration"] = (
    df_filtered["tpep_dropoff_datetime"] - df_filtered["tpep_pickup_datetime"]
).dt.total_seconds() / 60  


df_rel = df_filtered.copy()
plt.figure(figsize=(6,5))
plt.scatter(df_rel["trip_duration"], df_rel["fare_amount"], alpha=0.3)
plt.title("Fare Amount vs Trip Duration")
plt.xlabel("Trip Duration")
plt.ylabel("Fare Amount")
plt.show()

# %%
# Show relationship between fare and number of passengers
plt.figure(figsize=(6,5))
df_rel.boxplot(column="fare_amount", by="passenger_count")
plt.title("Fare Amount by Passenger Count")
plt.suptitle("")
plt.xlabel("Passenger Count")
plt.ylabel("Fare Amount")
plt.show()

# %%
# Show relationship between tip and trip distance
plt.figure(figsize=(6,5))
plt.scatter(df_rel["trip_distance"], df_rel["tip_amount"], alpha=0.3)
plt.title("Tip Amount vs Trip Distance")
plt.xlabel("Trip Distance")
plt.ylabel("Tip Amount")
plt.show()

# %% [markdown]
# **3.1.8** <font color = red>[3 marks]</font> <br>
# Analyse the distribution of different payment types (`payment_type`)

# %%
# Analyse the distribution of different payment types (payment_type).

payment_map = {
    1: "Credit Card",
    2: "Cash",
    3: "No Charge",
    4: "Dispute"
}

df["payment_label"] = df["payment_type"].map(payment_map)
payment_counts = df["payment_label"].value_counts()

plt.figure(figsize=(6,4))
payment_counts.plot(kind="bar")
plt.title("Distribution of Payment Types")
plt.xlabel("Payment Type")
plt.ylabel("Number of Trips")
plt.show()

# %% [markdown]
# - 1= Credit card
# - 2= Cash
# - 3= No charge
# - 4= Dispute

# %% [markdown]
# ##### Geographical Analysis

# %% [markdown]
# For this, you have to use the *taxi_zones.shp* file from the *taxi_zones* folder.
#
# There would be multiple files inside the folder (such as *.shx, .sbx, .sbn* etc). You do not need to import/read any of the files other than the shapefile, *taxi_zones.shp*.
#
# Do not change any folder structure - all the files need to be present inside the folder for it to work.
#
# The folder structure should look like this:
# ```
# Taxi Zones
# |- taxi_zones.shp.xml
# |- taxi_zones.prj
# |- taxi_zones.sbn
# |- taxi_zones.shp
# |- taxi_zones.dbf
# |- taxi_zones.shx
# |- taxi_zones.sbx
#
#  ```
#
#  You only need to read the `taxi_zones.shp` file. The *shp* file will utilise the other files by itself.

# %% [markdown]
# We will use the *GeoPandas* library for geopgraphical analysis
# ```
# import geopandas as gpd
# ```
#
# More about geopandas and shapefiles: [About](https://geopandas.org/en/stable/about.html)
#
#
# Reading the shapefile is very similar to *Pandas*. Use `gpd.read_file()` function to load the data (*taxi_zones.shp*) as a GeoDataFrame. Documentation: [Reading and Writing Files](https://geopandas.org/en/stable/docs/user_guide/io.html)

# %%
# !pip install geopandas
import sys
# !{sys.executable} -m pip install geopandas

# %% [markdown]
# **3.1.9** <font color = red>[2 marks]</font> <br>
# Load the shapefile and display it.

# %%
# import geopandas as gpd
import geopandas as gpd

zones = gpd.read_file("taxi_zones/taxi_zones.shp")
zones.head()
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry
# 0            EWR  POLYGON ((933100.918 192536.086, 933091.011 19...
# 1         Queens  MULTIPOLYGON (((1033269.244 172126.008, 103343...
# 2          Bronx  POLYGON ((1026308.77 256767.698, 1026495.593 2...
# 3      Manhattan  POLYGON ((992073.467 203714.076, 992068.667 20...
# 4  Staten Island  POLYGON ((935843.31 144283.336, 936046.565 144...

# %%
zones.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    263 non-null    int32
#  1   Shape_Leng  263 non-null    float64
#  2   Shape_Area  263 non-null    float64
#  3   zone        263 non-null    object
#  4   LocationID  263 non-null    int32
#  5   borough     263 non-null    object
#  6   geometry    263 non-null    geometry
# dtypes: float64(2), geometry(1), int32(2), object(2)
# memory usage: 12.5+ KB

# %% [markdown]
# Now, if you look at the DataFrame created, you will see columns like: `OBJECTID`,`Shape_Leng`, `Shape_Area`, `zone`, `LocationID`, `borough`, `geometry`.
# <br><br>
#
# Now, the `locationID` here is also what we are using to mark pickup and drop zones in the trip records.
#
# The geometric parameters like shape length, shape area and geometry are used to plot the zones on a map.
#
# This can be easily done using the `plot()` method.

# %%
# print(zones.info())
zones.plot()
# Out:
# <Axes: >

# %% [markdown]
# Now, you have to merge the trip records and zones data using the location IDs.

# %% [markdown]
# **3.1.10** <font color = red>[3 marks]</font> <br>
# Merge the zones data into trip data using the `locationID` and `PULocationID` columns.

# %%
# Merge zones and trip records using locationID and PULocationID
df["PULocationID"] = df["PULocationID"].astype(int)
zones["LocationID"] = zones["LocationID"].astype(int)

df_merged = df.merge(zones[["LocationID", "zone", "borough"]],left_on="PULocationID",right_on="LocationID",how="left")

# %%
df_merged[["PULocationID", "zone", "borough"]].head()
# Out:
#    PULocationID                   zone    borough
# 0           238  Upper West Side North  Manhattan
# 1           162           Midtown East  Manhattan
# 2           129        Jackson Heights     Queens
# 3            50           Clinton West  Manhattan
# 4           170            Murray Hill  Manhattan

# %% [markdown]
# **3.1.11** <font color = red>[3 marks]</font> <br>
# Group data by location IDs to find the total number of trips per location ID

# %%
# Group data by location and calculate the number of trips
zone_trip_counts = df_merged.groupby("zone").size().sort_values(ascending=False)

zone_trip_counts.head(10)
# Out:
# zone
# JFK Airport                     15281
# Upper East Side South           13656
# Midtown Center                  13436
# Upper East Side North           12090
# Midtown East                    10337
# LaGuardia Airport               10149
# Penn Station/Madison Sq West     9908
# Times Sq/Theatre District        9641
# Lincoln Square East              9468
# Midtown North                    8408
# dtype: int64

# %% [markdown]
# **3.1.12** <font color = red>[2 marks]</font> <br>
# Now, use the grouped data to add number of trips to the GeoDataFrame.
#
# We will use this to plot a map of zones showing total trips per zone.

# %%
# Merge trip counts back to the zones GeoDataFrame

zone_trip_df = zone_trip_counts.reset_index()
zone_trip_df.columns = ["zone", "trip_count"]

# %%
zones_merged = zones.merge(
    zone_trip_df,
    on="zone",
    how="left"
)

# To handle 0 trip count in zones
zones_merged["trip_count"] = zones_merged["trip_count"].fillna(0)
zones_merged[["zone", "trip_count"]].head()
# Out:
#                       zone  trip_count
# 0           Newark Airport        37.0
# 1              Jamaica Bay         1.0
# 2  Allerton/Pelham Gardens         5.0
# 3            Alphabet City       324.0
# 4            Arden Heights         4.0

# %% [markdown]
# The next step is creating a color map (choropleth map) showing zones by the number of trips taken.
#
# Again, you can use the `zones.plot()` method for this. [Plot Method GPD](https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.plot.html#geopandas.GeoDataFrame.plot)
#
# But first, you need to define the figure and axis for the plot.
#
# `fig, ax = plt.subplots(1, 1, figsize = (12, 10))`
#
# This function creates a figure (fig) and a single subplot (ax)
#
# ---

# %% [markdown]
# After setting up the figure and axis, we can proceed to plot the GeoDataFrame on this axis. This is done in the next step where we use the plot method of the GeoDataFrame.
#
# You can define the following parameters in the `zones.plot()` method:
# ```
# column = '',
# ax = ax,
# legend = True,
# legend_kwds = {'label': "label", 'orientation': "<horizontal/vertical>"}
# ```
#
# To display the plot, use `plt.show()`.

# %% [markdown]
# **3.1.13** <font color = red>[3 marks]</font> <br>
# Plot a color-coded map showing zone-wise trips

# %%
# Define figure and axis
fig, ax = plt.subplots(1, 1, figsize=(12, 10))

# Plot the choropleth map
zones_merged.plot(column="trip_count",ax=ax,legend=True,legend_kwds={"label": "Number of Trips", "orientation": "vertical"})

plt.title("Zone-wise Taxi Trips")
plt.show()

# %%
# can you try displaying the zones DF sorted by the number of trips?
zones_sorted = zones_merged.sort_values(by="trip_count", ascending=False)
zones_sorted[["zone", "borough", "trip_count"]].head(10)
# Out:
#                              zone    borough  trip_count
# 131                   JFK Airport     Queens     15281.0
# 236         Upper East Side South  Manhattan     13656.0
# 160                Midtown Center  Manhattan     13436.0
# 235         Upper East Side North  Manhattan     12090.0
# 161                  Midtown East  Manhattan     10337.0
# 137             LaGuardia Airport     Queens     10149.0
# 185  Penn Station/Madison Sq West  Manhattan      9908.0
# 229     Times Sq/Theatre District  Manhattan      9641.0
# 141           Lincoln Square East  Manhattan      9468.0
# 162                 Midtown North  Manhattan      8408.0

# %% [markdown]
# Here we have completed the temporal, financial and geographical analysis on the trip records.
#
# **Compile your findings from general analysis below:**

# %% [markdown]
# You can consider the following points:
#
# * Busiest hours, days and months
# * Trends in revenue collected
# * Trends in quarterly revenue
# * How fare depends on trip distance, trip duration and passenger counts
# * How tip amount depends on trip distance
# * Busiest zones

# %% [markdown]
# #### **3.2** Detailed EDA: Insights and Strategies
# <font color = red>[50 marks]</font> <br>

# %% [markdown]
# Having performed basic analyses for finding trends and patterns, we will now move on to some detailed analysis focussed on operational efficiency, pricing strategies, and customer experience.

# %% [markdown]
# ##### Operational Efficiency

# %% [markdown]
# Analyze variations by time of day and location to identify bottlenecks or inefficiencies in routes

# %% [markdown]
# **3.2.1** <font color = red>[3 marks]</font> <br>
# Identify slow routes by calculating the average time taken by cabs to get from one zone to another at different hours of the day.

# %% [markdown]
# Speed on a route *X* for hour *Y* = (*distance of the route X / average trip duration for hour Y*)

# %%
# Find routes which have the slowest speeds at different times of the day

df_merged["tpep_pickup_datetime"] = pd.to_datetime(df_merged["tpep_pickup_datetime"])
df_merged["tpep_dropoff_datetime"] = pd.to_datetime(df_merged["tpep_dropoff_datetime"])

df_merged["trip_duration"] = (df_merged["tpep_dropoff_datetime"]- df_merged["tpep_pickup_datetime"]).dt.total_seconds() / 60

df_merged["trip_duration_hr"] = df_merged["trip_duration"] / 60

df_speed = df_merged[(df_merged["trip_distance"] > 0) &(df_merged["trip_duration_hr"] > 0)].copy()

df_speed["route"] = (df_speed["PULocationID"].astype(str)+ "-"+ df_speed["DOLocationID"].astype(str))
route_stats = df_speed.groupby(["route", "pickup_hour"]).agg({"trip_distance": "mean","trip_duration_hr": "mean"}).reset_index()

route_stats["avg_speed_mph"] = route_stats["trip_distance"] /route_stats["trip_duration_hr"]

slow_routes = route_stats.sort_values("avg_speed_mph").head(10)
slow_routes
# Out:
#            route  pickup_hour  trip_distance  trip_duration_hr  avg_speed_mph
# 44227   24-107.0           20           0.01          0.526944       0.018977
# 31345  193-264.0           14           0.01          0.480833       0.020797
# 47982  261-261.0            9           0.19          7.713519       0.024632
# 4241   114-193.0           21           0.56         18.130833       0.030887
# 6236    13-211.0            0           1.37         23.939167       0.057228
# 31902  211-107.0           14           1.74         23.356944       0.074496
# 15720  141-264.0            8           1.83         23.267222       0.078651
# 29510  173-173.0           11           0.20          2.499722       0.080009
# 47403  256-232.0           20           1.89         23.504167       0.080411
# 3442   113-244.0            9           0.42          4.956389       0.084739

# %% [markdown]
# How does identifying high-traffic, high-demand routes help us?

# %% [markdown]
# **3.2.2** <font color = red>[3 marks]</font> <br>
# Calculate the number of trips at each hour of the day and visualise them. Find the busiest hour and show the number of trips for that hour.

# %%
# Visualise the number of trips per hour and find the busiest hour

hourly_trips = df_merged.groupby("pickup_hour").size().sort_index()

plt.figure(figsize=(8,5))
hourly_trips.plot(kind="bar")
plt.title("Number of Trips by Hour of Day")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Trips")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Remember, we took a fraction of trips. To find the actual number, you have to scale the number up by the sampling ratio.

# %%
busiest_hour = hourly_trips.idxmax()
max_trips = hourly_trips.max()

print("Busiest hour:", busiest_hour)
print("Number of trips:", max_trips)
# Out:
# Busiest hour: 18
# Number of trips: 20260
# Estimated trips at busiest hour: 405200

# %% [markdown]
# **3.2.3** <font color = red>[2 mark]</font> <br>
# Find the actual number of trips in the five busiest hours

# %%
# Scale up the number of trips

sample_fraction = 0.05 # 5 % SAMPLE
scaling_factor = 1 / sample_fraction

estimated_trips = max_trips * scaling_factor

estimated_trips
# Out:
# np.float64(405200.0)

# %% [markdown]
# **3.2.4** <font color = red>[3 marks]</font> <br>
# Compare hourly traffic pattern on weekdays. Also compare for weekend.

# %%
# Compare traffic trends for the week days and weekends
df["day_of_week"] = df["tpep_pickup_datetime"].dt.day_name()

df["day_type"] = df["day_of_week"].isin(["Saturday", "Sunday"]).map({True: "Weekend", False: "Weekday"})
traffic_trend = df.groupby(["pickup_hour", "day_type"]).size().reset_index(name="num_trips")
traffic_pivot = traffic_trend.pivot(
    index="pickup_hour",
    columns="day_type",
    values="num_trips"
)

plt.figure(figsize=(10,5))
traffic_pivot.plot()
plt.title("Weekday vs Weekend Traffic Trend")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Trips")
plt.xticks(range(24))
plt.grid(True)
plt.show()

# %% [markdown]
# What can you infer from the above patterns? How will finding busy and quiet hours for each day help us?

# %% [markdown]
# **3.2.5** <font color = red>[3 marks]</font> <br>
# Identify top 10 zones with high hourly pickups. Do the same for hourly dropoffs. Show pickup and dropoff trends in these zones.

# %%
# Find top 10 pickup and dropoff zones
pickup_hourly = df_merged.groupby(["zone", "pickup_hour"]).size().reset_index(name="pickup_trips")
pickup_zone_total = pickup_hourly.groupby("zone")["pickup_trips"].sum().sort_values(ascending=False)


top_pickup_zones = pickup_zone_total.head(10)
top_pickup_zones
# Out:
# zone
# JFK Airport                     15281
# Upper East Side South           13656
# Midtown Center                  13436
# Upper East Side North           12090
# Midtown East                    10337
# LaGuardia Airport               10149
# Penn Station/Madison Sq West     9908
# Times Sq/Theatre District        9641
# Lincoln Square East              9468
# Midtown North                    8408
# Name: pickup_trips, dtype: int64

# %%
df_drop = df.merge(
    zones[["LocationID", "zone", "borough"]],
    left_on="DOLocationID",
    right_on="LocationID",
    how="left"
)

# %%
drop_hourly = df_drop.groupby(["zone", "pickup_hour"]).size().reset_index(name="drop_trips")
drop_zone_total = drop_hourly.groupby("zone")["drop_trips"].sum().sort_values(ascending=False)


top_drop_zones = drop_zone_total.head(10)
top_drop_zones
# Out:
# zone
# Upper East Side North        12764
# Upper East Side South        12082
# Midtown Center               11314
# Times Sq/Theatre District     8842
# Murray Hill                   8320
# Midtown East                  8154
# Lincoln Square East           8044
# Upper West Side South         7998
# Lenox Hill West               7655
# Midtown North                 7299
# Name: drop_trips, dtype: int64

# %%
top_pick_zones_list = top_pickup_zones.index.tolist()

pickup_trend_top = pickup_hourly[pickup_hourly["zone"].isin(top_pick_zones_list)]
plt.figure(figsize=(12,6))

for z in top_pick_zones_list:
    temp = pickup_trend_top[pickup_trend_top["zone"] == z]
    plt.plot(temp["pickup_hour"], temp["pickup_trips"], label=z)

plt.title("Hourly Pickup Trends — Top Zones")
plt.xlabel("Hour")
plt.ylabel("Trips")
plt.legend(bbox_to_anchor=(1.05,1))
plt.show()

# %%
top_drop_zones_list = top_drop_zones.index.tolist()

drop_trend_top = drop_hourly[drop_hourly["zone"].isin(top_drop_zones_list)]
plt.figure(figsize=(12,6))

for z in top_drop_zones_list:
    temp = drop_trend_top[drop_trend_top["zone"] == z]
    plt.plot(temp["pickup_hour"], temp["drop_trips"], label=z)

plt.title("Hourly Dropoff Trends — Top Zones")
plt.xlabel("Hour")
plt.ylabel("Trips")
plt.legend(bbox_to_anchor=(1.05, 1))
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **3.2.6** <font color = red>[3 marks]</font> <br>
# Find the ratio of pickups and dropoffs in each zone. Display the 10 highest (pickup/drop) and 10 lowest (pickup/drop) ratios.

# %%
# Find the top 10 and bottom 10 pickup/dropoff ratios
pickup_total = df_merged.groupby("zone").size().rename("pickups")
drop_total = df_drop.groupby("zone").size().rename("dropoffs")

ratio_df = pd.concat([pickup_total, drop_total], axis=1).fillna(0)

ratio_df["pickup_drop_ratio"] = ratio_df["pickups"] / ratio_df["dropoffs"]
highest_ratio = ratio_df.sort_values("pickup_drop_ratio", ascending=False).head(10)
highest_ratio
# Out:
#                               pickups  dropoffs  pickup_drop_ratio
# zone
# East Elmhurst                  1335.0       178           7.500000
# JFK Airport                   15281.0      3416           4.473361
# LaGuardia Airport             10149.0      3427           2.961482
# Penn Station/Madison Sq West   9908.0      6148           1.611581
# Greenwich Village South        3777.0      2693           1.402525
# Central Park                   4890.0      3508           1.393957
# West Village                   6399.0      4751           1.346874
# Midtown East                  10337.0      8154           1.267721
# Garment District               4748.0      3916           1.212462
# Midtown Center                13436.0     11314           1.187555

# %%
lowest_ratio = ratio_df.sort_values("pickup_drop_ratio", ascending=True).head(10)
lowest_ratio
# Out:
#                                      pickups  dropoffs  pickup_drop_ratio
# zone
# Westerleigh                              0.0         4                0.0
# Crotona Park                             0.0         2                0.0
# Bronx Park                               0.0        20                0.0
# Heartland Village/Todt Hill              0.0         5                0.0
# Breezy Point/Fort Tilden/Riis Beach      0.0         9                0.0
# Bay Terrace/Fort Totten                  0.0        41                0.0
# Mariners Harbor                          0.0         7                0.0
# Grymes Hill/Clifton                      0.0         3                0.0
# New Dorp/Midland Beach                   0.0         1                0.0
# Oakwood                                  0.0         1                0.0

# %% [markdown]
# **3.2.7** <font color = red>[3 marks]</font> <br>
# Identify zones with high pickup and dropoff traffic during night hours (11PM to 5AM)

# %%
# During night hours (11pm to 5am) find the top 10 pickup and dropoff zones
# Note that the top zones should be of night hours and not the overall top zones
night_df = df_merged[(df_merged["pickup_hour"] >= 23) |(df_merged["pickup_hour"] <= 5)]

night_pickups = (
    night_df.groupby("zone")
    .size()
    .sort_values(ascending=False)
    .head(10)
)

night_pickups
# Out:
# zone
# East Village                    2456
# JFK Airport                     2375
# West Village                    1901
# Clinton East                    1647
# Lower East Side                 1518
# Greenwich Village South         1365
# Times Sq/Theatre District       1261
# Penn Station/Madison Sq West    1101
# Midtown South                    969
# LaGuardia Airport                941
# dtype: int64

# %%
night_df_drop = df_drop[
    (df_drop["pickup_hour"] >= 23) |
    (df_drop["pickup_hour"] <= 5)
]

night_dropoffs = (
    night_df_drop.groupby("zone")
    .size()
    .sort_values(ascending=False)
    .head(10)
)
night_dropoffs
# Out:
# zone
# East Village                     1314
# Clinton East                     1091
# Murray Hill                       979
# East Chelsea                      961
# Gramercy                          959
# Lenox Hill West                   866
# Yorkville West                    858
# West Village                      756
# Sutton Place/Turtle Bay North     750
# Times Sq/Theatre District         720
# dtype: int64

# %%
ratio_df["pickup_drop_ratio"] = (ratio_df["pickups"] /ratio_df["dropoffs"].replace(0, np.nan))
ratio_df
# Out:
#                            pickups  dropoffs  pickup_drop_ratio
# zone
# Allerton/Pelham Gardens        5.0        22           0.227273
# Alphabet City                324.0      1096           0.295620
# Arden Heights                  4.0         5           0.800000
# Arrochar/Fort Wadsworth        1.0         3           0.333333
# Astoria                      136.0       855           0.159064
# ...                            ...       ...                ...
# Port Richmond                  0.0         1           0.000000
# Rossville/Woodrow              0.0         3           0.000000
# Saint George/New Brighton      0.0         9           0.000000
# West Brighton                  0.0         5           0.000000
# Westerleigh                    0.0         4           0.000000
#
# [256 rows x 3 columns]

# %% [markdown]
# Now, let us find the revenue share for the night time hours and the day time hours. After this, we will move to deciding a pricing strategy.
#
# **3.2.8** <font color = red>[2 marks]</font> <br>
# Find the revenue share for nighttime and daytime hours.

# %%
# Filter for night hours (11 PM to 5 AM)

df["is_night"] = (df["pickup_hour"] >= 23) |(df["pickup_hour"] <= 5)

df["time_period"] = df["is_night"].map({
    True: "Night",
    False: "Day"
})

revenue_share = df.groupby("time_period")["total_amount"].sum()
revenue_share_pct = (revenue_share / revenue_share.sum() * 100).round(2)

revenue_share_pct
# Out:
# time_period
# Day      87.85
# Night    12.15
# Name: total_amount, dtype: float64

# %%
revenue_share_pct.plot(kind="pie", autopct="%1.1f%%")
plt.title("Revenue Share: Night vs Day")
plt.ylabel("")
plt.show()

# %% [markdown]
# ##### Pricing Strategy

# %% [markdown]
# **3.2.9** <font color = red>[2 marks]</font> <br>
# For the different passenger counts, find the average fare per mile per passenger.
#
# For instance, suppose the average fare per mile for trips with 3 passengers is 3 USD/mile, then the fare per mile per passenger will be 1 USD/mile.

# %%
# Analyse the fare per mile per passenger for different passenger counts
df_fare = df[(df["trip_distance"] > 0) & (df["passenger_count"] > 0)].copy()

df_fare["fare_per_mile"] = df_fare["fare_amount"] / df_fare["trip_distance"]
df_fare["fare_per_mile_per_passenger"] = df_fare["fare_per_mile"] / df_fare["passenger_count"]

fare_pp = df_fare.groupby("passenger_count")["fare_per_mile_per_passenger"].mean().sort_index()


fare_pp
# Out:
# passenger_count
# 1    10.745210
# 2     7.027095
# 3     4.740845
# 4     4.040163
# 5     1.584292
# 6     1.444870
# Name: fare_per_mile_per_passenger, dtype: float64

# %%
plt.figure(figsize=(8,4))
fare_pp.plot(kind="bar")
plt.title("Average Fare per Mile per Passenger")
plt.xlabel("Passenger Count")
plt.ylabel("Fare per Mile per Passenger ($)")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **3.2.10** <font color = red>[3 marks]</font> <br>
# Find the average fare per mile by hours of the day and by days of the week

# %%
# Compare the average fare per mile for different days and for different times of the day
df_fpm = df[df["trip_distance"] > 0].copy()

df_fpm["fare_per_mile"] = df_fpm["fare_amount"] / df_fpm["trip_distance"]
fare_by_hour = df_fpm.groupby("pickup_hour")["fare_per_mile"].mean().sort_index()

plt.figure(figsize=(10,5))
fare_by_hour.plot(kind="line", marker="o")
plt.title("Average Fare per Mile by Hour of Day")
plt.xlabel("Hour of Day")
plt.ylabel("Average Fare per Mile ($)")
plt.grid(alpha=0.3)
plt.show()

# %%
df_fpm["day_of_week"] = df_fpm["tpep_pickup_datetime"].dt.day_name()
fare_by_day = df_fpm.groupby("day_of_week")["fare_per_mile"].mean()

order = ["Monday","Tuesday","Wednesday","Thursday",
         "Friday","Saturday","Sunday"]

fare_by_day = fare_by_day.reindex(order)
plt.figure(figsize=(10,5))
fare_by_day.plot(kind="bar")
plt.title("Average Fare per Mile by Day of Week")
plt.xlabel("Day")
plt.ylabel("Average Fare per Mile ($)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **3.2.11** <font color = red>[3 marks]</font> <br>
# Analyse the average fare per mile for the different vendors for different hours of the day

# %%
# Compare fare per mile for different vendors
vendor_hour = df_fpm.groupby(["VendorID","pickup_hour"])["fare_per_mile"].mean().reset_index()

vendor_pivot = vendor_hour.pivot(index="pickup_hour",columns="VendorID",values="fare_per_mile")

plt.figure(figsize=(10,5))
vendor_pivot.plot()

plt.title("Fare per Mile by Vendor and Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Average Fare per Mile ($)")
plt.grid(alpha=0.3)
plt.show()
# Out:
# /var/folders/4k/567n_rrn7tdchkf86355f2lc0000gn/T/ipykernel_90113/1286455855.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   vendor_hour = df_fpm.groupby(["VendorID","pickup_hour"])["fare_per_mile"].mean().reset_index()

# %% [markdown]
# **3.2.12** <font color = red>[5 marks]</font> <br>
# Compare the fare rates of the different vendors in a tiered fashion. Analyse the average fare per mile for distances upto 2 miles. Analyse the fare per mile for distances from 2 to 5 miles. And then for distances more than 5 miles.

# %%
# Defining distance tiers

df_tier = df.copy()
df_tier = df_tier[df_tier["trip_distance"] > 0]
df_tier["fare_per_mile"] = df_tier["fare_amount"] / df_tier["trip_distance"]

# %%
def distance_tier(d):
    if d <= 2:
        return "0-2 miles"
    elif d <= 5:
        return "2-5 miles"
    else:
        return "5+ miles"

df_tier["distance_tier"] = df_tier["trip_distance"].apply(distance_tier)

vendor_tier_fare = df_tier.groupby(["VendorID", "distance_tier"])["fare_per_mile"].mean().reset_index()

vendor_tier_fare
# Out:
# /var/folders/4k/567n_rrn7tdchkf86355f2lc0000gn/T/ipykernel_90113/2842598500.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   vendor_tier_fare = df_tier.groupby(["VendorID", "distance_tier"])["fare_per_mile"].mean().reset_index()
#   VendorID distance_tier  fare_per_mile
# 0      1.0     0-2 miles       9.922685
# 1      1.0     2-5 miles       6.377335
# 2      1.0      5+ miles       4.423019
# 3      2.0     0-2 miles      18.306793
# 4      2.0     2-5 miles       6.544056
# 5      2.0      5+ miles       4.498730

# %%
pivot_vendor_tier = vendor_tier_fare.pivot(
    index="distance_tier",
    columns="VendorID",
    values="fare_per_mile"
)

pivot_vendor_tier
# Out:
# VendorID            1.0        2.0
# distance_tier
# 0-2 miles      9.922685  18.306793
# 2-5 miles      6.377335   6.544056
# 5+ miles       4.423019   4.498730

# %%
plt.figure(figsize=(8,5))
pivot_vendor_tier.plot(kind="bar")
plt.title("Average Fare per Mile by Vendor and Distance Tier")
plt.xlabel("Distance Tier")
plt.ylabel("Average Fare per Mile ($)")
plt.xticks(rotation=0)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ##### Customer Experience and Other Factors

# %% [markdown]
# **3.2.13** <font color = red>[5 marks]</font> <br>
# Analyse average tip percentages based on trip distances, passenger counts and time of pickup. What factors lead to low tip percentages?

# %%
#  Analyze tip percentages based on distances, passenger counts and pickup times

df_tip = df[(df["fare_amount"] > 0)].copy()

df_tip["tip_pct"] = (df_tip["tip_amount"] / df_tip["fare_amount"]) * 100

df_tip["tip_pct"].describe()
# Out:
# count    286766.000000
# mean         20.416570
# std          23.342986
# min           0.000000
# 25%           7.812500
# 50%          23.902439
# 75%          29.154930
# max        5000.000000
# Name: tip_pct, dtype: float64

# %%
df_tip["distance_tier"] = pd.cut(
    df_tip["trip_distance"],
    bins=[0, 2, 5, df_tip["trip_distance"].max()],
    labels=["0-2 miles", "2-5 miles", "5+ miles"]
)

tip_by_distance = df_tip.groupby("distance_tier")["tip_pct"].mean()

plt.figure(figsize=(6,4))
tip_by_distance.plot(kind="bar")
plt.title("Average Tip % by Distance Tier")
plt.ylabel("Average Tip %")
plt.xticks(rotation=0)
plt.show()
# Out:
# /var/folders/4k/567n_rrn7tdchkf86355f2lc0000gn/T/ipykernel_90113/3224155796.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tip_by_distance = df_tip.groupby("distance_tier")["tip_pct"].mean()

# %%
tip_by_passenger = df_tip.groupby("passenger_count")["tip_pct"].mean()

plt.figure(figsize=(6,4))
tip_by_passenger.plot(kind="bar")
plt.title("Average Tip % by Passenger Count")
plt.ylabel("Average Tip %")
plt.xticks(rotation=0)
plt.show()

# %%
tip_by_hour = df_tip.groupby("pickup_hour")["tip_pct"].mean()

plt.figure(figsize=(8,4))
tip_by_hour.plot()
plt.title("Average Tip % by Pickup Hour")
plt.xlabel("Hour")
plt.ylabel("Average Tip %")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# Additional analysis [optional]: Let's try comparing cases of low tips with cases of high tips to find out if we find a clear aspect that drives up the tipping behaviours

# %%
# Compare trips with tip percentage < 10% to trips with tip percentage > 25%
df_tip["tpep_pickup_datetime"] = pd.to_datetime(df_tip["tpep_pickup_datetime"])
df_tip["tpep_dropoff_datetime"] = pd.to_datetime(df_tip["tpep_dropoff_datetime"])

df_tip["trip_duration"] = (df_tip["tpep_dropoff_datetime"]- df_tip["tpep_pickup_datetime"]).dt.total_seconds() / 60

low_tip = df_tip[df_tip["tip_pct"] < 10]
high_tip = df_tip[df_tip["tip_pct"] > 25]

comparison = pd.DataFrame({
    "Metric": ["Avg Distance", "Avg Fare", "Avg Duration", "Avg Passengers"],
    "Low Tip (<10%)": [
        low_tip["trip_distance"].mean(),
        low_tip["fare_amount"].mean(),
        low_tip["trip_duration"].mean(),
        low_tip["passenger_count"].mean()
    ],
    "High Tip (>25%)": [
        high_tip["trip_distance"].mean(),
        high_tip["fare_amount"].mean(),
        high_tip["trip_duration"].mean(),
        high_tip["passenger_count"].mean()
    ]
})

comparison
# Out:
#            Metric  Low Tip (<10%)  High Tip (>25%)
# 0    Avg Distance        3.795409         2.293178
# 1        Avg Fare       21.696822        14.434128
# 2    Avg Duration       19.559261        12.667828
# 3  Avg Passengers        1.429128         1.359946

# %% [markdown]
# **3.2.14** <font color = red>[3 marks]</font> <br>
# Analyse the variation of passenger count across hours and days of the week.

# %%
# See how passenger count varies across hours and days
passenger_by_hour = df.groupby("pickup_hour")["passenger_count"].mean()

plt.figure(figsize=(8,4))
passenger_by_hour.plot()
plt.title("Average Passenger Count by Hour")
plt.xlabel("Hour")
plt.ylabel("Average Passengers")
plt.grid(alpha=0.3)
plt.show()

# %%
df["pickup_day"] = pd.to_datetime(df["tpep_pickup_datetime"]).dt.day_name()
passenger_by_day = df.groupby("pickup_day")["passenger_count"].mean()
order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
passenger_by_day = passenger_by_day.reindex(order)

plt.figure(figsize=(7,4))
passenger_by_day.plot(kind="bar")
plt.title("Average Passenger Count by Day")
plt.ylabel("Average Passengers")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **3.2.15** <font color = red>[2 marks]</font> <br>
# Analyse the variation of passenger counts across zones

# %%
# How does passenger count vary across zones

passenger_by_zone = (df_merged.groupby("zone")["passenger_count"].mean().reset_index(name="avg_passenger_count"))


passenger_by_zone.head()
# Out:
#                       zone  avg_passenger_count
# 0  Allerton/Pelham Gardens             1.000000
# 1            Alphabet City             1.459877
# 2            Arden Heights             1.000000
# 3  Arrochar/Fort Wadsworth             3.000000
# 4                  Astoria             1.419118

# %%
# For a more detailed analysis, we can use the zones_with_trips GeoDataFrame
# Create a new column for the average passenger count in each zone.

zone_trips = (df_merged.groupby("zone").size().reset_index(name="num_trips"))

passenger_by_zone = (df_merged.groupby("zone")["passenger_count"].mean().reset_index(name="avg_passenger_count"))
zones_with_trips = zones.merge(zone_trips, on="zone", how="left")
zones_with_trips = zones_with_trips.merge(passenger_by_zone,on="zone",how="left")
zones_with_trips["avg_passenger_count"] = zones_with_trips["avg_passenger_count"].fillna(0)

# %%
plt.figure(figsize=(10,8))
zones_with_trips.plot(column="avg_passenger_count",cmap="viridis",legend=True,edgecolor="black")
plt.title("Average Passenger Count by Zone")
plt.axis("off")
plt.show()

# %%
top_passenger_zones = passenger_by_zone.sort_values("avg_passenger_count", ascending=False).head(10)

low_passenger_zones = passenger_by_zone.sort_values( "avg_passenger_count").head(10)
top_passenger_zones, low_passenger_zones
# Out:
# (                             zone  avg_passenger_count
#  3         Arrochar/Fort Wadsworth             3.000000
#  52              Crotona Park East             2.250000
#  176               Randalls Island             2.250000
#  161           Ocean Parkway South             2.000000
#  9                    Battery Park             1.805085
#  144                Middle Village             1.777778
#  233     Williamsburg (South Side)             1.745455
#  56             DUMBO/Vinegar Hill             1.705882
#  72              East Williamsburg             1.705882
#  85   Flushing Meadows-Corona Park             1.603175,
#                                    zone  avg_passenger_count
#  0              Allerton/Pelham Gardens                  1.0
#  81                Flatbush/Ditmas Park                  1.0
#  174                    Queensboro Hill                  1.0
#  78                        Far Rockaway                  1.0
# ...

# %% [markdown]
# Find out how often surcharges/extra charges are applied to understand their prevalance

# %% [markdown]
# **3.2.16** <font color = red>[5 marks]</font> <br>
# Analyse the pickup/dropoff zones or times when extra charges are applied more frequently

# %%
# How often is each surcharge applied?
surcharge_cols = ["extra","mta_tax","tolls_amount","improvement_surcharge","congestion_surcharge", "airport_fee"]

surcharge_cols = [c for c in surcharge_cols if c in df_merged.columns]
surcharge_freq = {}

for col in surcharge_cols:
    surcharge_freq[col] = (df_merged[col] > 0).mean() * 100

surcharge_freq = pd.Series(surcharge_freq).sort_values(ascending=False)
surcharge_freq
# Out:
# improvement_surcharge    99.967232
# mta_tax                  99.031252
# congestion_surcharge     92.215153
# extra                    62.083907
# tolls_amount              8.116013
# dtype: float64

# %%
df_merged.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee', 'pickup_hour',
#        'pickup_month', 'pickup_weekday', 'payment_label', 'LocationID', 'zone',
#        'borough', 'trip_duration', 'trip_duration_hr'],
#       dtype='object')

# %%
extra_by_hour = (df_merged.groupby("pickup_hour")["extra"].apply(lambda x: (x > 0).mean() * 100))
plt.figure(figsize=(8,4))
extra_by_hour.plot()
plt.title("Extra Surcharge Frequency by Hour")
plt.ylabel("% Trips with Extra")
plt.xlabel("Hour")
plt.grid(alpha=0.3)
plt.show()

# %%
extra_by_zone = (df_merged.groupby("zone")["extra"].apply(lambda x: (x > 0).mean() * 100).sort_values(ascending=False).head(10))

extra_by_zone
# Out:
# zone
# Ocean Parkway South                100.000000
# Arrochar/Fort Wadsworth            100.000000
# Country Club                       100.000000
# Jamaica Bay                        100.000000
# Stapleton                          100.000000
# Douglaston                         100.000000
# Marine Park/Floyd Bennett Field    100.000000
# LaGuardia Airport                   98.866883
# East Elmhurst                       83.146067
# Lower East Side                     82.715209
# Name: extra, dtype: float64

# %%
zone_lookup = zones[["LocationID", "zone"]].rename(columns={"zone": "drop_zone"})

df_merged = df_merged.merge(zone_lookup,left_on="DOLocationID",right_on="LocationID", how="left")
extra_by_drop_zone = (df_merged.groupby("drop_zone")["extra"].apply(lambda x: (x > 0).mean() * 100).sort_values(ascending=False).head(10))
extra_by_drop_zone
# Out:
# drop_zone
# Green-Wood Cemetery                  100.000000
# Arrochar/Fort Wadsworth              100.000000
# Eltingville/Annadale/Prince's Bay    100.000000
# Grymes Hill/Clifton                  100.000000
# Jamaica Bay                          100.000000
# Great Kills                          100.000000
# LaGuardia Airport                     98.191365
# Saint George/New Brighton             88.888889
# Windsor Terrace                       86.065574
# Carroll Gardens                       84.583333
# Name: extra, dtype: float64

# %% [markdown]
# ## **4** Conclusion
# <font color = red>[15 marks]</font> <br>

# %% [markdown]
# ### **4.1** Final Insights and Recommendations
# <font color = red>[15 marks]</font> <br>
#
# Conclude your analyses here. Include all the outcomes you found based on the analysis.
#
# Based on the insights, frame a concluding story explaining suitable parameters such as location, time of the day, day of the week etc. to be kept in mind while devising a strategy to meet customer demand and optimise supply.

# %% [markdown]
# **4.1.1** <font color = red>[5 marks]</font> <br>
# Recommendations to optimize routing and dispatching based on demand patterns and operational inefficiencies

# %% [markdown]
# Key Analysis Findings
#
# - Taxi demand is highly time dependent, with peak pickups during evening hours (5–8 PM) and lowest activity in early morning (3–6 AM).
#
# - High-demand zones are concentrated in Midtown Manhattan and airport areas (JFK, LaGuardia).
#
# - Several zones show pickup–dropoff imbalance, indicating inefficient vehicle distribution.
#
# - Slow routes are primarily observed in core Manhattan during peak hours due to congestion.
#
# - Most trips are short-distance and single-passenger dominated.
#
# Recommendations
#
# - Implement time aware dispatch: Pre-position drivers near high-demand zones before evening peaks and reduce supply during low-demand hours.
#
# - Enable zone-based reblancing: Continuously shift idle/empty vehicles from high dropoff zones to high pickup zones to avoid vehicle overcrowding.
#
# - Adopt congestion aware routing: Use realtime traffic data to avoid slow corridors and improve trips per driver per hour.
#
# -  Strengthen airport fleet planning: Maintain dedicated vehicle pools near airports to handle demand and higher surcharge trips.
#
# - Optimize short trip handling: Prioritize quick turnaround in dense urban zones where short trips generate high per-mile revenue.
#
# Business Impact
#
# - Reduced passenger wait times
#
# - Improved driver utilization
#
# - Better fleet productivity
#
# - Increased overall revenue efficiency

# %% [markdown]
# **4.1.2** <font color = red>[5 marks]</font> <br>
#
# Suggestions on strategically positioning cabs across different zones to make best use of insights uncovered by analysing trip trends across time, days and months.

# %% [markdown]
# Key Insights from Analysis
#
# - Demand is highest during evening commute hours and weekend nights.
#
# - Midtown Manhattan and airport zones consistently show the strongest pickup activity.
#
# - Pickup and dropoff imbalances exist in several zones, causing vehicle accumulation in low demand areas.
#
# - Night time demand shifts more toward residential and entertainment districts.
#
# - Most trips are short distance and single passenger dominated.
#
# Strategic Positioning Recommendations
#
# - Pre-position fleet in peak zones: Deploy more cabs in Midtown and major commercial areas before evening rush hours.
#
# - Maintain airport buffers: Keep dedicated cab availability near JFK and LaGuardia to capture steady high value trips.
#
# - Dynamic zone rebalancing: Continuously move idle vehicles from drop heavy zones to pickup heavy zones.
#
# - Weekend/night focus: Increase cab density in nightlife and residential hubs during late evenings and weekends.
#
# - Lesser early-morning supply: Reduce fleet presence during low demand early morning hours to minimize idle time.
#
# - Support short trip zones: Ensure quicker vehicle circulation in more populayed urban zones where short distance trips are most common.

# %% [markdown]
# **4.1.3** <font color = red>[5 marks]</font> <br>
# Propose data-driven adjustments to the pricing strategy to maximize revenue while maintaining competitive rates with other vendors.

# %% [markdown]
# Key Insights
#
# - Short trips generate the highest fare per mile.
#
# - Evening and weekend periods show the strongest demand.
#
# - Airport and congestion zones frequently include surcharges.
#
# - Vendor pricing is mostly similar, with small gaps on short trips.
#
# Recommended Pricing Adjustments
#
# - Use time based dynamic pricing: Slightly increase fares during evening peak hours and weekend nights when demand is highest.
#
# - Offer off-peak incentives: Provide small discounts in early morning and low-demand hours to stimulate ridership.
#
# - Optimize short trips pricing carefully: Maintain strong per mile revenue on short trips but avoid overpricing compared to competitors.
#
# - Leverage airport demand: Apply premium pricing or bundles for airport routes where willingness to pay is higher.
#
# - Encourage shared rides: Offer per passenger discounts for multi passenger trips to improve vehicle utilization.
#
# - Monitor competitor parity: Keep Vendor pricing within a competitive band, especially for medium and long trips.
#
# Expected Impact
#
# - Higher revenue during peak demand
#
# - Better utilization during slow hours
#
# - Competitive positioning vs other vendors
